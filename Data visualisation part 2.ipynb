# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pd.read_csv('C:\\Users\\dunneli\\OneDrive - RTÉ\\Desktop\\2022.csv')
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 141   142    Botswana*           3,471        3,667       3,275
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# 1                        2,226                        1,953
# ...

# %%
report2022 = pd.read_csv('C:\\Users\\dunneli\\OneDrive - RTÉ\\Desktop\\2022.csv')

# %%
report2022.dtypes
# Out:
# RANK                                           int64
# Country                                       object
# Happiness score                               object
# Whisker-high                                  object
# Whisker-low                                   object
# Dystopia (1.83) + residual                    object
# Explained by: GDP per capita                  object
# Explained by: Social support                  object
# Explained by: Healthy life expectancy         object
# Explained by: Freedom to make life choices    object
# Explained by: Generosity                      object
# Explained by: Perceptions of corruption       object
# dtype: object

# %%
report2022 = pd.read_csv('C:\\Users\\dunneli\\OneDrive - RTÉ\\Desktop\\2022.csv')

# %%
report2022.head
# Out:
# <bound method NDFrame.head of      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 141   142    Botswana*           3,471        3,667       3,275
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# ...

# %%
plt.plot(report2022['RANK'],report2022['Happiness score'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4f2514f1a505> in <module>
# ----> 1 plt.plot(report2022['RANK'],report2022['Happiness score'])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...

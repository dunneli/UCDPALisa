# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pd.read_csv('C:\\Users\\dunneli\\OneDrive - RTÉ\\Desktop\\2022.csv')
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 141   142    Botswana*           3,471        3,667       3,275
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# 1                        2,226                        1,953
# ...

# %%
Report2022 = pd.read_csv('C:\\Users\\dunneli\\OneDrive - RTÉ\\Desktop\\2022.csv')

# %%
Report2022.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
Report2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
# ...

# %%
Report2022['Country']
# Out:
# 0          Finland
# 1          Denmark
# 2          Iceland
# 3      Switzerland
# 4      Netherlands
#           ...
# 141      Botswana*
# 142        Rwanda*
# 143       Zimbabwe
# 144        Lebanon
# 145    Afghanistan
# Name: Country, Length: 146, dtype: object

# %%
Report2022[['RANK', 'Country', 'Happiness score']]
# Out:
#      RANK      Country Happiness score
# 0       1      Finland           7,821
# 1       2      Denmark           7,636
# 2       3      Iceland           7,557
# 3       4  Switzerland           7,512
# 4       5  Netherlands           7,415
# ..    ...          ...             ...
# 141   142    Botswana*           3,471
# 142   143      Rwanda*           3,268
# 143   144     Zimbabwe           2,995
# 144   145      Lebanon           2,955
# 145   146  Afghanistan           2,404
#
# [146 rows x 3 columns]

# %%
Report2022[0:5][['RANK', 'Country', 'Happiness score']]
# Out:
#    RANK      Country Happiness score
# 0     1      Finland           7,821
# 1     2      Denmark           7,636
# 2     3      Iceland           7,557
# 3     4  Switzerland           7,512
# 4     5  Netherlands           7,415

# %%
Report2022.iloc[0:10]
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
# 5     6  Luxembourg*           7,404        7,501       7,307
# 6     7       Sweden           7,384        7,454       7,315
# 7     8       Norway           7,365        7,440       7,290
# 8     9       Israel           7,364        7,426       7,301
# 9    10  New Zealand           7,200        7,279       7,120
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# ...

# %%
Report2022.iloc[0:20, 0:3]
# Out:
#     RANK         Country Happiness score
# 0      1         Finland           7,821
# 1      2         Denmark           7,636
# 2      3         Iceland           7,557
# 3      4     Switzerland           7,512
# 4      5     Netherlands           7,415
# 5      6     Luxembourg*           7,404
# 6      7          Sweden           7,384
# 7      8          Norway           7,365
# 8      9          Israel           7,364
# 9     10     New Zealand           7,200
# 10    11         Austria           7,163
# 11    12       Australia           7,162
# 12    13         Ireland           7,041
# 13    14         Germany           7,034
# 14    15          Canada           7,025
# 15    16   United States           6,977
# 16    17  United Kingdom           6,943
# 17    18         Czechia           6,920
# 18    19         Belgium           6,805
# 19    20          France           6,687

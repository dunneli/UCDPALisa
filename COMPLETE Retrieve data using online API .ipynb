# %%
#I couldn't find a relevant API, so that is why this is separate to the rest of the project
import requests

# %%
requests.get('https://www.rte.ie/sport/results/rugby/mens-six-nations-championship/16285/tables/')
# Out:
# <Response [200]>

# %%
rte = requests.get('https://www.rte.ie/sport/results/rugby/mens-six-nations-championship/16285/tables/')

# %% [raw]
# rte.

# %%
rte.headers
# Out:
# {'Date': 'Mon, 11 Apr 2022 14:21:05 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Cache-Control': 'max-age=0, s-maxage=120, must-revalidate, public, stale-if-error=1800, stale-while-revalidate=30', 'X-Frame-Options': 'DENY', 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'Cross-Origin-Opener-Policy': 'same-origin', 'Content-Language': 'en', 'Vary': 'Accept-Language, Accept-Encoding', 'X-Info': 'mt-web2 0 184877362, django3 184877363', 'Last-Modified': 'Mon, 11 Apr 2022 11:54:36 GMT', 'CF-Cache-Status': 'HIT', 'Age': '0', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Permissions-Policy': 'interest-cohort=()', 'Server': 'cloudflare', 'CF-RAY': '6fa45dddddc760d3-DUB', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400, h3-29=":443"; ma=8
# ...

# %%
rte.content
# Out:
# b'\n<!DOCTYPE html>\n<html class="no-js" lang="en">\n<head>\n\n<script src="https://cdn.cookielaw.org/consent/a58df52b-2812-4cc9-99c6-cf9bcfe5af8b/OtAutoBlock.js" type="text/javascript"></script>\n<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="a58df52b-2812-4cc9-99c6-cf9bcfe5af8b"></script>\n<script src="https://www.rte.ie/djstatic/dotie/privacy/cookie-functions.js?v=20220411v0"></script>\n<script type="text/javascript">\n    var optanonCallbacks = [\n        __eraseIllegalCookies\n    ];\n    function OptanonWrapper() {\n        for (var i = 0; i < optanonCallbacks.length; i++) {\n            optanonCallbacks[i].call();\n        }\n    }\n</script>\n\n<meta charset="utf-8" />\n<meta http-equiv="x-ua-compatible" content="ie=edge" />\n<meta name="viewport" content="width=device-width, height=device-height, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n<title>Latest Men&#x27;s Six Nations Cha
# ...

# %%
import requests
import pandas as pd

# %%
uni = requests.get('http://universities.hipolabs.com/search?country=United States')
pd.DataFrame(uni.json()).head()
# Out:
#   state-province        country                                   name  \
# 0           None  United States                    Marywood University
# 1           None  United States                  Lindenwood University
# 2           None  United States                    Sullivan University
# 3           None  United States  Florida State College at Jacksonville
# 4           None  United States                      Xavier University
#
#                       web_pages           domains alpha_two_code
# 0     [http://www.marywood.edu]    [marywood.edu]             US
# 1  [http://www.lindenwood.edu/]  [lindenwood.edu]             US
# 2       [https://sullivan.edu/]    [sullivan.edu]             US
# 3       [https://www.fscj.edu/]        [fscj.edu]             US
# 4     [https://www.xavier.edu/]      [xavier.edu]             US

# %%
met = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers')
pd.DataFrame(met.json()).head()
# Out:
#    total  objectIDs
# 0     85     436524
# 1     85     484935
# 2     85     437112
# 3     85     210191
# 4     85     431264

# %%
MCU = requests.get('https://www.whenisthenextmcufilm.com/api')
pd.DataFrame(MCU.json()).head()
# Out:
#               days_until                               following_production  \
# days_until            23                                                 58
# overview              23  A great student, avid gamer, and voracious fan...
# poster_url            23  https://image.tmdb.org/t/p/w500/nDBf9PaiBrp5xI...
# release_date          23                                         2022-06-08
# title                 23                                         Ms. Marvel
#
#                                                        overview  \
# days_until    Doctor Strange, with the help of mystical alli...
# overview      Doctor Strange, with the help of mystical alli...
# poster_url    Doctor Strange, with the help of mystical alli...
# release_date  Doctor Strange, with the help of mystical alli...
# title         Doctor Strange, with the help of mystical alli...
#
#                                                      poster_url release_date  \
# ...
